# %%
# Sentinel line breaker は必ずつけること！

# %%
# ひとつの Insertion

# %% [markdown]
# $$
# \begin{align}
# a &= b \\
# \end{align}
# $$

# %%
# ひとつの Replacement

# %% [markdown]
# $$
# \begin{align}
# a &= b \tag 1 \\
# \end{align}
# $$
